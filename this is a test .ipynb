# %%
import pandas as pd
df= pd.read_csv("D:\\data anlysis\\data sets\\NCHS_-_Leading_Causes_of_Death__United_States.csv")
df.head(10)
# Out:
#    Year                                     113 Cause Name      Cause Name  \
# 0  2012  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 1  2016  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 2  2013  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 3  2000  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
# 4  2014  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 5  2009  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
# 6  2011  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 7  2015  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 8  2014  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 9  2013  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
#
#                   State  Deaths  Age-adjusted Death Rate
# 0               Vermont      21                      2.6
# ...

# %%
df.shape
# Out:
# (10296, 6)

# %%
rows , columns = df.shape
print(rows)
# Out:
# 10296

# %%
df[20:25]
# Out:
#     Year                                     113 Cause Name      Cause Name  \
# 20  2002  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 21  2000  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 22  2005  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
# 23  2015  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 24  2004  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
#
#                    State  Deaths  Age-adjusted Death Rate
# 20            Washington     306                      5.4
# 21            Washington     293                      5.4
# 22  District of Columbia      33                      5.4
# 23               Arizona     458                      5.5
# 24  District of Columbia      33                      5.5

# %%
df.columns
# Out:
# Index(['Year', '113 Cause Name', 'Cause Name', 'State', 'Deaths',
#        'Age-adjusted Death Rate'],
#       dtype='object')

# %%
df[['Year','Cause Name', 'State', 'Deaths',
       'Age-adjusted Death Rate']]
# Out:
#        Year      Cause Name                 State  Deaths  \
# 0      2012  Kidney disease               Vermont      21
# 1      2016  Kidney disease               Vermont      30
# 2      2013  Kidney disease               Vermont      30
# 3      2000         Suicide  District of Columbia      23
# 4      2014  Kidney disease               Arizona     325
# 5      2009         Suicide  District of Columbia      29
# 6      2011  Kidney disease          South Dakota      49
# 7      2015  Kidney disease               Vermont      39
# 8      2014  Kidney disease               Vermont      37
# 9      2013  Kidney disease               Arizona     374
# 10     2015         Suicide  District of Columbia      34
# 11     2001  Kidney disease            Washington     279
# 12     1999         Suicide  District of Columbia      30
# 13     1999  Kidney disease            Washington     278
# 14     2016         Suicide  District of Columbia      40
# ...

# %%
df['Deaths'].max()
# Out:
# 2744248

# %%
df[['Deaths']].mean()
# Out:
# Deaths    15367.932789
# dtype: float64

# %%
df.describe()
# Out:
#                Year        Deaths  Age-adjusted Death Rate
# count  10296.000000  1.029600e+04             10296.000000
# mean    2007.500000  1.536793e+04               128.037383
# std        5.188379  1.121457e+05               224.381865
# min     1999.000000  2.100000e+01                 2.600000
# 25%     2003.000000  6.060000e+02                19.200000
# 50%     2007.500000  1.704500e+03                35.800000
# 75%     2012.000000  5.678000e+03               153.025000
# max     2016.000000  2.744248e+06              1087.300000

# %%
df[df.Year>2006]
# Out:
#        Year                                     113 Cause Name  \
# 0      2012  Nephritis, nephrotic syndrome and nephrosis (N...
# 1      2016  Nephritis, nephrotic syndrome and nephrosis (N...
# 2      2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 4      2014  Nephritis, nephrotic syndrome and nephrosis (N...
# 5      2009  Intentional self-harm (suicide) (*U03,X60-X84,...
# 6      2011  Nephritis, nephrotic syndrome and nephrosis (N...
# 7      2015  Nephritis, nephrotic syndrome and nephrosis (N...
# 8      2014  Nephritis, nephrotic syndrome and nephrosis (N...
# 9      2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 10     2015  Intentional self-harm (suicide) (*U03,X60-X84,...
# 14     2016  Intentional self-harm (suicide) (*U03,X60-X84,...
# 18     2011  Nephritis, nephrotic syndrome and nephrosis (N...
# 19     2008  Nephritis, nephrotic syndrome and nephrosis (N...
# 23     2015  Nephritis, nephrotic syndrome and nephrosis (N...
# ...

# %%
df[df.Deaths==df['Deaths'].max()]
# Out:
#       Year 113 Cause Name  Cause Name          State   Deaths  \
# 9601  2016     All Causes  All causes  United States  2744248
#
#       Age-adjusted Death Rate
# 9601                    728.8

# %% [markdown]
# <h2>This is to copy a column and add it to the data frame again this is could help</h2>

# %%
newArr=[]
for i in df.Year :
    newArr.append(i)

df['newArr']=newArr
df.head()
# Out:
#    Year                                     113 Cause Name      Cause Name  \
# 0  2012  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 1  2016  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 2  2013  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 3  2000  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
# 4  2014  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
#
#                   State  Deaths  Age-adjusted Death Rate  newArr
# 0               Vermont      21                      2.6    2012
# 1               Vermont      30                      3.7    2016
# 2               Vermont      30                      3.8    2013
# 3  District of Columbia      23                      3.8    2000
# 4               Arizona     325                      4.1    2014

# %% [markdown]
# <h2>here we created a new data frame with the columns which i need only </h2>

# %%
my_df=df[['Year','Cause Name','State','Age-adjusted Death Rate']]
my_df.head()
# Out:
#    Year      Cause Name                 State  Age-adjusted Death Rate
# 0  2012  Kidney disease               Vermont                      2.6
# 1  2016  Kidney disease               Vermont                      3.7
# 2  2013  Kidney disease               Vermont                      3.8
# 3  2000         Suicide  District of Columbia                      3.8
# 4  2014  Kidney disease               Arizona                      4.1

# %%
new_df =my_df.groupby('Year')
new_df.mean()
# Out:
#       Age-adjusted Death Rate
# Year
# 1999               143.517657
# 2000               142.217133
# 2001               140.362762
# 2002               139.978497
# 2003               138.022203
# 2004               132.391958
# 2005               132.766434
# 2006               128.669231
# 2007               126.036713
# 2008               125.900874
# 2009               121.587063
# 2010               121.234965
# 2011               120.057517
# 2012               118.287413
# 2013               118.104895
# 2014               117.617308
# 2015               119.385315
# 2016               118.534965

# %%
Year_df=new_df.sum()
Year_df.sort_values('Year',ascending=False,inplace=True)
Year_df.plot.bar(figsize=(14,6))

# %%
new_df =my_df.groupby('State')
State_df=new_df.sum()
State_df.drop(columns=['Year'],inplace=True)
State_df.sort_values('Deaths',ascending=False,inplace=True)
#State_df.plot.bar(figsize=(14,6))
topdf=State_df[1:20]
topdf
# Out:
#                  Deaths
# State
# California      7694563
# Florida         5512136
# Texas           5192340
# New York        4889235
# Pennsylvania    4069680
# Ohio            3501123
# Illinois        3299528
# Michigan        2839241
# North Carolina  2447232
# New Jersey      2267451
# Georgia         2182235
# Tennessee       1889824
# Virginia        1871444
# Indiana         1821157
# Missouri        1796910
# Massachusetts   1712812
# Washington      1535878
# Wisconsin       1515656
# Alabama         1510931

# %%
State_df.head(10)
# Out:
#                   Deaths
# State
# United States   79114118
# California       7694563
# Florida          5512136
# Texas            5192340
# New York         4889235
# Pennsylvania     4069680
# Ohio             3501123
# Illinois         3299528
# Michigan         2839241
# North Carolina   2447232

# %%
Top10States=State_df.head(10)
topdf.plot.bar(figsize=(14,6))

# %%
new_df =my_df.groupby('Cause Name')
Cause_df=new_df.sum()
Cause_df.drop(columns=['Year'],inplace=True)
Cause_df.sort_values('Deaths',ascending=False,inplace=True)
Cause_df.plot.bar(y='Deaths',figsize=(10,6))

# %%
Suicide_df=my_df[my_df['Cause Name']=='Suicide']
gr=Suicide_df.groupby('Year')
gr.sum().plot.bar(figsize=(14,6))

# %%
Canser_df=my_df[my_df['Cause Name']=='Cancer']
cn=Canser_df.groupby('Year')
cn.sum().plot(figsize=(14,6))

# %%
dfAge=df[['Year','Cause Name','State','Age-adjusted Death Rate']]
Canser_df2=dfAge[dfAge['Cause Name']=='Cancer']
cn2=Canser_df2.groupby('Year')
cn2.mean().plot.bar(figsize=(14,6))

# %%
state=dfAge['State'].unique().tolist()
causes=dfAge['Cause Name'].unique().tolist()
year=dfAge['Year'].unique().tolist()

# %%
graph_df=pd.DataFrame(index=year,columns = state)
graph_df.sort_index(inplace=True)   
graph_df.head()
# Out:
#      Vermont District of Columbia Arizona South Dakota Washington Iowa  \
# 1999     NaN                  NaN     NaN          NaN        NaN  NaN
# 2000     NaN                  NaN     NaN          NaN        NaN  NaN
# 2001     NaN                  NaN     NaN          NaN        NaN  NaN
# 2002     NaN                  NaN     NaN          NaN        NaN  NaN
# 2003     NaN                  NaN     NaN          NaN        NaN  NaN
#
#      New York Massachusetts New Jersey California  ... Virginia Kansas  \
# 1999      NaN           NaN        NaN        NaN  ...      NaN    NaN
# 2000      NaN           NaN        NaN        NaN  ...      NaN    NaN
# 2001      NaN           NaN        NaN        NaN  ...      NaN    NaN
# 2002      NaN           NaN        NaN        NaN  ...      NaN    NaN
# 2003      NaN           NaN        NaN        NaN  ...      NaN    NaN
#
#      Wisconsin North Carolina Alabama Kentucky Missouri Oklahoma  \
# ...

# %%
Two_arr=[]

gb = dfAge.groupby('State')
for s in state :
    x=gb.get_group(s).set_index('Year').sort_index()
    allcauses=x[x['Cause Name']=='All causes'] 
    graph_df[s]=allcauses['Age-adjusted Death Rate'].tolist()
graph_df
# Out:
#       Vermont  District of Columbia  Arizona  South Dakota  Washington   Iowa  \
# 1999    812.9                1087.3    818.4         808.4       815.1  806.4
# 2000    821.8                1061.2    810.4         805.7       804.6  794.7
# 2001    819.6                1049.9    795.9         790.0       799.4  780.1
# 2002    786.8                1034.1    811.2         778.6       795.0  779.9
# 2003    779.7                 993.0    798.4         796.6       789.2  776.2
# 2004    749.4                 972.1    771.1         752.4       751.9  738.3
# 2005    751.6                 970.6    786.7         770.7       757.6  757.5
# 2006    728.0                 951.7    767.1         752.5       731.2  736.1
# 2007    733.0                 911.2    731.0         712.9       731.9  724.2
# 2008    722.5                 897.6    714.5         731.9       734.3  752.6
# 2009    683.2                 833.3    693.8         706.2       708.4  723.0
# ...

# %%
graph_df.describe()
# Out:
#           Vermont  District of Columbia     Arizona  South Dakota  Washington  \
# count   18.000000             18.000000   18.000000     18.000000   18.000000
# mean   741.733333            893.216667  735.938889    743.250000  733.022222
# std     44.176451            125.250541   57.631437     39.514052   50.451836
# min    683.200000            743.800000  661.700000    679.300000  672.000000
# 25%    711.450000            759.400000  684.400000    713.450000  688.150000
# 50%    725.250000            904.400000  722.750000    726.250000  731.550000
# 75%    772.675000            987.775000  793.600000    776.625000  781.300000
# max    821.800000           1087.300000  818.400000    808.400000  815.100000
#
#              Iowa    New York  Massachusetts  New Jersey  California  ...  \
# count   18.000000   18.000000      18.000000   18.000000   18.000000  ...
# mean   745.777778  713.161111     725.088889  741.088889  695.155556  ...
# ...

# %%
#graph_df.plot(figsize=(14,6))
newgh=graph_df[["District of Columbia",'Arizona','Washington','New York','North Carolina']]
newgh.plot(figsize=(14,6))

# %% [markdown]
# <h2>plot shows comparsion between all states the the and avarage death rate in the last 5 years </h2>

# %%
graph_df.head().mean().plot.bar(figsize=(14,6))

# %%
graph_df2=pd.DataFrame(index=year,columns = causes)
graph_df2.sort_index(inplace=True)   
graph_df2.head()
# Out:
#      Kidney disease Suicide Alzheimer's disease Influenza and pneumonia  \
# 1999            NaN     NaN                 NaN                     NaN
# 2000            NaN     NaN                 NaN                     NaN
# 2001            NaN     NaN                 NaN                     NaN
# 2002            NaN     NaN                 NaN                     NaN
# 2003            NaN     NaN                 NaN                     NaN
#
#      Diabetes CLRD Unintentional injuries Stroke Heart disease Cancer  \
# 1999      NaN  NaN                    NaN    NaN           NaN    NaN
# 2000      NaN  NaN                    NaN    NaN           NaN    NaN
# 2001      NaN  NaN                    NaN    NaN           NaN    NaN
# 2002      NaN  NaN                    NaN    NaN           NaN    NaN
# 2003      NaN  NaN                    NaN    NaN           NaN    NaN
#
#      All causes
# 1999        NaN
# 2000        NaN
# 2001        NaN
# 2002        NaN
# 2003        NaN

# %%
Twoo_arr=[]

gb = dfAge.groupby('Cause Name')
for s in causes :
    x=gb.get_group(s).set_index('Year').sort_index()
    allcauses=x[x['State']=='United States'] 
    graph_df2[s]=allcauses['Age-adjusted Death Rate'].tolist()
graph_df2
# Out:
#       Kidney disease  Suicide  Alzheimer's disease  Influenza and pneumonia  \
# 1999            13.0     10.5                 16.5                     23.5
# 2000            13.5     10.4                 18.1                     23.7
# 2001            14.1     10.7                 19.3                     22.2
# 2002            14.4     11.0                 20.8                     23.2
# 2003            14.7     10.8                 22.1                     22.6
# 2004            14.5     11.0                 22.6                     20.4
# 2005            14.7     10.9                 24.0                     21.0
# 2006            14.8     11.0                 23.7                     18.4
# 2007            14.9     11.3                 23.8                     16.8
# 2008            15.1     11.6                 25.8                     17.6
# 2009            15.1     11.8                 24.2                     16.5
# ...

# %%
graph_df2.plot.bar(figsize=(17,10))

# %% [markdown]
# <h2>some of information i discoverd from this plot </h2>
# <li>1-the deaths cancer is decresing very slowly </li>
#    <li> 2-heart disease is decresing fast and it could be lower than the cancer in the future </li>
#     <li>3-Alzheimer's disease is increasing </li>
#   <li>  4-Stroke at first was causes more deaths but Unintentional injuries is more than it</li>
#    <li> 5- all other causes is Almost changed.</li>

# %%
graph_df2.mean().plot.bar(figsize=(17,6))

# %% [markdown]
# <h2>in the previous figure we can see that the heart disease and cancer is extreamly dangerous if compaerd with other causes </h2>
